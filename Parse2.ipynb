# %%
pip install tabula-py pandas
# Out:
# Requirement already satisfied: tabula-py in c:\users\mathe\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (2.9.0)
# Requirement already satisfied: pandas in c:\users\mathe\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (2.2.0)
# Requirement already satisfied: numpy in c:\users\mathe\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tabula-py) (1.26.3)
# Requirement already satisfied: distro in c:\users\mathe\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tabula-py) (1.9.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\mathe\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\mathe\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\mathe\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas) (2023.4)
# Requirement already satisfied: six>=1.5 in c:\users\mathe\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from openpyxl import load_workbook
from openpyxl.utils import column_index_from_string, get_column_letter
import csv
import pandas as pd

caminho_arquivo = 'arquivo2.xlsx'

workbook = load_workbook(filename=caminho_arquivo)
sheet = workbook.active

# %%
#DADOS DO ALUNO

texto_procurado = "NOME DO (A) ALUNO (A)"


coluna = 'E'
coluna_alvo = sheet[f'E']
nomes_encontrados = []
dados_encontrados = []

encontrado = False
for cell in coluna_alvo:
    if cell.value and texto_procurado in str(cell.value):
        # Verifica se a próxima célula na mesma coluna existe e obtém seu valor
        if cell.row < sheet.max_row:
          nome = sheet[f'{coluna}{cell.row + 1}'].value
          forma_ingresso = sheet[f'{"R"}{cell.row + 1}'].value

          if nome not in nomes_encontrados:
            nomes_encontrados.append(nome)
            dados_encontrados.append([nome, forma_ingresso])
          encontrado = True

if not encontrado:
    print("O texto não foi encontrado na coluna especificada.")


# Escrevendo os dados encontrados em um arquivo CSV
data_alunos = 'alunos.csv'

with open(data_alunos, mode='w', newline='', encoding='utf-8') as arquivo_csv:
    writer = csv.writer(arquivo_csv)
    # Cabeçalho do CSV
    writer.writerow(['nome_aluno', 'forma_ingresso'])

    for dados in dados_encontrados:
        writer.writerow(dados)

df = pd.read_csv(data_alunos)
df

# %%
#GRADE

import csv
import pandas as pd

texto_procurado = "CÓDIGO"
coluna = 'C'
coluna_alvo = sheet[f'{coluna}']

encontrado = False
codigos_encontrados = []
dados_encontrados = []

for cell in coluna_alvo:
    if cell.value and texto_procurado in str(cell.value):
        linha = cell.row + 2
        curriculo = sheet[f'AA{linha - 10}'].value
        if curriculo == 'SI01':
          curriculo = '1'
        else:
          curriculo = '2'

        while True:
            codigo = sheet[f'{coluna}{linha}'].value
            disciplina = sheet[f'F{linha}'].value
            carga = sheet[f'S{linha}'].value
            credito = sheet[f'U{linha}'].value


            if None not in [codigo, disciplina, carga, credito] and codigo not in codigos_encontrados:
                dados_encontrados.append([codigo, disciplina, carga, credito, curriculo])
                codigos_encontrados.append(codigo)

            linha += 1

            if linha > sheet.max_row or texto_procurado in str(sheet[f'{coluna}{linha}'].value):
                break

        # break

# Escrevendo os dados encontrados em um arquivo CSV
data_grade = 'grade.csv'

with open(data_grade, mode='w', newline='', encoding='utf-8') as arquivo_csv:
    writer = csv.writer(arquivo_csv)
    # Cabeçalho do CSV
    writer.writerow(['cod_disciplina', 'nome_disciplina', 'carga_horaria', 'credito', 'curriculo'])

    for dados in dados_encontrados:
        writer.writerow(dados)

print(f"Os dados foram salvos no arquivo CSV: {data_grade}")

# Lendo o arquivo CSV como um DataFrame do pandas
df = pd.read_csv(data_grade)
df

# %%
#HISTORICO

import csv
import pandas as pd

coluna = 'E'
texto_procurado = "NOME DO (A) ALUNO (A)"
texto_divisao = "Curso"
texto_divisao2 = "CARGA HORÁRIA"
linhas_none = 0
coluna_alvo = sheet[f'{coluna}']
encontrado = False
dados_encontrados = []

for cell in coluna_alvo:
    if cell.value and texto_procurado in str(cell.value):
        linha = cell.row + 1
        nome  = sheet[f'{coluna}{linha}'].value
        linha = cell.row + 9

        while True:
            if encontrado:
                while linhas_none <= 50:
                    cell.row = linha
                    cellalvo = sheet[f'{coluna}{linha}'].value
                    if  texto_procurado == cellalvo:
                        linhas_none = 0
                        linha = cell.row + 1
                        nome  = sheet[f'{coluna}{linha}'].value
                        linha = cell.row + 9
                        encontrado = False
                        break
                    elif cellalvo is None:
                        linhas_none += 1
                    linha += 1
            
            ano = sheet[f'A{linha}'].value
            codigo     = sheet[f'C{linha}'].value
            disciplina = sheet[f'F{linha}'].value
            nota       = sheet[f'X{linha}'].value
            situacao   = sheet[f'Z{linha}'].value
            
            if disciplina is not None:
                dados_encontrados.append([ano, nome, codigo, disciplina, nota, situacao])            
            linha += 1

            if linha < sheet.max_row:
                if texto_divisao in str(sheet[f'L{linha}'].value) or texto_divisao2 in str(sheet[f'A{linha}'].value):
                    encontrado = True
            else:
                break

        
        
        break


# Escrevendo os dados encontrados em um arquivo CSV
data_grade = 'historico.csv'

with open(data_grade, mode='w', newline='', encoding='utf-8') as arquivo_csv:
    writer = csv.writer(arquivo_csv)
    # Cabeçalho do CSV
    writer.writerow(['ano', 'nome', 'codigo', 'disciplina', 'nota', 'situacao'])

    for dados in dados_encontrados:
        writer.writerow(dados)

print(f"Os dados foram salvos no arquivo CSV: {data_grade}")

# Lendo o arquivo CSV como um DataFrame do pandas
df = pd.read_csv(data_grade)
df
# Out:
# Os dados foram salvos no arquivo CSV: historico.csv
#        ano             nome    codigo                             disciplina  \
# 0     2008  Isadora Isabela  OCRQ3517                    Storytelling Visual
# 1     2008  Isadora Isabela  RJGL2456                    Design Colaborativo
# 2     2008  Isadora Isabela  QBWW6998                     Computacao Grafica
# 3     2008  Isadora Isabela  UFMQ0127                Design para Longevidade
# 4     2008  Isadora Isabela  MKUB0718                   Design de Mobiliario
# ...    ...              ...       ...                                    ...
# 1826  2017  Elisa Valentina  QBWW6998                     Computacao Grafica
# 1827  2017  Elisa Valentina  UFMQ0127                Design para Longevidade
# 1828  2017  Elisa Valentina  MKUB0718                   Design de Mobiliario
# 1829  2017  Elisa Valentina  BKII1063  Design de Visualizacao de Informacoes
# 1830  2017  Elisa Valentina  RJYZ5864                      Identidade Visual
#
#       nota             situacao
# 0     5.53             APROVADO
# 1     5.63             APROVADO
# 2     7.00   APROVADO POR MÉDIA
# 3     3.38            REPROVADO
# 4     9.00   APROVADO POR MÉDIA
# ...    ...                  ...
# 1826   NaN  REPROVADO POR FALTA
# 1827   NaN  REPROVADO POR FALTA
# 1828   NaN  REPROVADO POR FALTA
# 1829   NaN  REPROVADO POR FALTA
# 1830   NaN  REPROVADO POR FALTA
#
# [1831 rows x 6 columns]

# %%
from openpyxl import load_workbook
from openpyxl.utils import column_index_from_string, get_column_letter
import csv
import pandas as pd

caminho_arquivo = 'arquivos_2/arquivo2.xlsx'

workbook = load_workbook(filename=caminho_arquivo)
sheet = workbook.active
# Out:
# C:\Users\mathe\AppData\Local\Temp\ipykernel_12448\2006277268.py:4: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
#STATUS ALUNO

import csv
import pandas as pd

texto_procurado = "NOME DO (A) ALUNO (A)"
texto_divisao = "Curso"
texto_divisao2 = "CARGA HORÁRIA"
coluna = 'E'
linhas_none = 0
coluna_alvo = sheet[f'{coluna}']
encontrado = False
dados_encontrados = []
nomes_encontrados = []

for cell in coluna_alvo:
    if cell.value and texto_procurado in str(cell.value):
        linha = cell.row + 1
        nome  = sheet[f'{coluna}{linha}'].value
        linha = cell.row + 9

        while True:
            if encontrado:
                while linhas_none <= 50:
                    cell.row = linha
                    cellalvo = sheet[f'{coluna}{linha}'].value
                    if  texto_procurado == cellalvo:
                        linhas_none = 0
                        linha = cell.row + 1
                        nome  = sheet[f'{coluna}{linha}'].value
                        linha = cell.row + 9
                        encontrado = False
                        break
                    elif cellalvo is None:
                        linhas_none += 1
                    linha += 1
            
            celula_status = sheet[f'F{linha}'].value
            
            if 'DESLIGAMENTO' == celula_status: 
                status = sheet[f'F{linha}'].value
            
            elif 'DESVINCULADO' == celula_status: 
                status = sheet[f'F{linha}'].value
            
            elif 'REINTEGRAÇÃO' == celula_status: 
                status = sheet[f'F{linha}'].value

            elif 'FORMADO' == celula_status: 
                status = sheet[f'F{linha}'].value
       

            linha += 1

            if linha < sheet.max_row:
                if texto_procurado in str(sheet[f'{coluna}{linha}'].value):
                    if nome not in nomes_encontrados:
                        nomes_encontrados.append(nome)
                        dados_encontrados.append([nome, status])

                        status = 'CURSANDO'
                    encontrado = True
            else:
                break
        
        break


# Escrevendo os dados encontrados em um arquivo CSV
data_grade = 'status_aluno.csv'

with open(data_grade, mode='w', newline='', encoding='utf-8') as arquivo_csv:
    writer = csv.writer(arquivo_csv)
    # Cabeçalho do CSV
    writer.writerow(['nome', 'status'])

    for dados in dados_encontrados:
        writer.writerow(dados)

print(f"Os dados foram salvos no arquivo CSV: {data_grade}")

# Lendo o arquivo CSV como um DataFrame do pandas
df = pd.read_csv(data_grade)
df
# Out:
# Os dados foram salvos no arquivo CSV: status_aluno.csv
#                  nome    status
# 0     Isadora Isabela   FORMADO
# 1      Michele Otavio  CURSANDO
# 2      Valeria Camila  CURSANDO
# 3    Fernando Vanessa  CURSANDO
# 4      Isadora Daniel  CURSANDO
# 5      Eduardo Marcos   FORMADO
# 6        Diego Sophie  CURSANDO
# 7        Joao Gustavo  CURSANDO
# 8       Alice Ricardo   FORMADO
# 9     Elisa Valentina  CURSANDO
# 10         Joao Maria  CURSANDO
# 11       Enzo Isadora   FORMADO
# 12  Guilherme Juliana  CURSANDO
# 13     Caua Guilherme   FORMADO
# 14         Julia Raul   FORMADO
# 15   Vinicius Roberto  CURSANDO
# 16      Pablo Michele  CURSANDO
# 17      Pablo Eduardo   FORMADO
# 18       Bruno Miguel  CURSANDO
# 19      Melissa Alice  CURSANDO
# 20        Lorena Luiz  CURSANDO
# 21       Nicolas Jose   FORMADO
# 22    Leticia Larissa  CURSANDO
# 23        Julia Diego  CURSANDO
# 24    Manuela Gustavo  CURSANDO
# 25    Gabriel Isabela  CURSANDO
# 26     Luciana Rafael  CURSANDO
# 27        Maria Livia  CURSANDO
# 28      Hugo Fernando  CURSANDO
# 29        Jose Sophie   FORMADO
# 30       Livia Otavio   FORMADO
# 31    Leonardo Lorena  CURSANDO
# 32        Renan Laura  CURSANDO
# 33    Alana Nathanael  CURSANDO
# 34      Leandro Julia  CURSANDO
# 35   Catarina Viviane   FORMADO
# 36     Felipe Leandro   FORMADO
# 37      Bruna Juliana  CURSANDO
# 38       Arthur Bruna  CURSANDO
# 39      Nicolas Lucas   FORMADO
# 40    Beatriz Eduarda   FORMADO
# 41          Joao Luan   FORMADO
# 42       Felipe Eloah  CURSANDO
# 43  Caroline Catarina  CURSANDO
# 44     Melissa Thales  CURSANDO
# 45     Leticia Bianca  CURSANDO
# 46    Mateus Vinicius   FORMADO
# 47     Mauricio Diego  CURSANDO
# 48        Evelyn Hugo  CURSANDO
# 49      Clara Nicolas  CURSANDO
# 50     Miguel Michele   FORMADO
# 51    Cecilia Viviane  CURSANDO
# 52         Hugo Pedro  CURSANDO

# %%
import pandas as pd

# Leitura do arquivo CSV

df = pd.read_csv('grade.csv')

# Filtrar as linhas que contêm informações sobre docentes
docentes_df = df[df['nome_disciplina'].str.contains("DOCENTE\(S\)")]

# Extrair os nomes dos docentes
nomes_docentes = docentes_df['nome_disciplina'].str.extract(r'DOCENTE\(S\):(.+)$')[0].str.strip()

# Verificar e armazenar os nomes únicos em um conjunto (set)
nomes_unicos = set()
for nome in nomes_docentes:
    if nome not in nomes_unicos:
        nomes_unicos.add(nome)

# Exibir os nomes únicos dos docentes
print("Nomes únicos dos docentes:")
print(nomes_unicos)

# Salvar os nomes únicos dos docentes em um arquivo CSV
nomes_unicos_df = pd.DataFrame(list(nomes_unicos), columns=['Nome'])
nomes_unicos_df.to_csv('professores.csv', index=False)
print("Nomes únicos dos docentes salvos em 'nomes_docentes_unicos.csv'")
# Out:
# Nomes únicos dos docentes:
# set()
# Nomes únicos dos docentes salvos em 'nomes_docentes_unicos.csv'
